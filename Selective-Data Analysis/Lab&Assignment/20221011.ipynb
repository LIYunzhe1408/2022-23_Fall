# %% [markdown]
# # NumPy

# %%
import numpy as np

# %% [markdown]
# ## ndarray

# %%
arr1 = np.array([1,2,3], dtype=np.float64)

# %% [markdown]
# dtype是NumPy灵活交互其它系统的源泉。
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
arr = np.array([1,2,3,4,5])
arr.dtype
# Out:
# dtype('int32')

# %%
a = arr.astype('string_')
a.dtype
# Out:
# dtype('S11')

# %% [markdown]
# ### 对应元素运算

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr + arr
# Out:
# array([ 2,  4,  6,  8, 10])

# %%
1 / arr
# Out:
# array([1.        , 0.5       , 0.33333333, 0.25      , 0.2       ])

# %% [markdown]
# ### 广播

# %%
arr
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr[2:4] = 12
arr
# Out:
# array([ 1,  2, 12, 12,  5])

# %% [markdown]
# ### 一个方便的方式

# %%
arr
# Out:
# array([ 1,  2, 12, 12,  5])

# %%
arr = [1,2,12,12,5]
arr[i  > 10] = 0
arr
# Out:
# [1, 0, 12, 12, 5]

# %% [markdown]
# ### 用数组表达式代替循环
